# %% [markdown]
# # Mixmosa Dating App Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Quick guide for better understanding of the data:
# - iq_share_correct ---> % of correct answers in a test
# - BIG 5 ----> 0-50
# - Physical attractiveness ---> 0-10
# - Height ----> 55-80 inches (139.7-203.2 cm)
# - income bucket ----> 1-9
# - Nicotine -----> NO/YES
# - Alcohol -----> 0-3
# - Marijuana -----> 0-3
# - Psychedelics -----> NO/YES
# - Behavioral health -----> 0-4
# - Sex partners score -----> 0-4
# - Get along with family -----> NO/YES
# - Political importance score -----> 0-4
# - Ethnicity Importance score -----> 0-2
# - Religion Importance score -----> 0-2
# - Politics importance score -----> 0-2
# - Mum children wanted score -----> 0-3
# - Already has kids -----> NO/YES
# - Casual sex score -----> 0-4
# - Hard work and success belief -----> 0-4

# %% [markdown]
# ## Exploratory data analysis

# %%
user_features = pd.read_csv('../csv/user_features.csv')

# %%
user_features.head()
# Out:
#                         user_id  age  gender attracted_to  iq_share_correct  \
# 0  N2QikIhXWyaoVSkD22KSatymXry1   33    male        women               NaN
# 1  a0qF436mgXPGArB23AD56eCA4CM2   33    male        women               NaN
# 2  8flwy3Pu0xdaJETKL7km2UfUTOh1   32    male        women               NaN
# 3  GD1gM3nQi0QKEukab2PNEQO2gvF2   30  female          men               NaN
# 4  rqVRyEhy97WenlbS8Vd0q6Fs6xf1   28  female          men               NaN
#
#    agreeableness  conscientiousness  extraversion  neuroticism  openness  ...  \
# 0            NaN                NaN           NaN          NaN       NaN  ...
# 1            NaN                NaN           NaN          NaN       NaN  ...
# 2            NaN                NaN           NaN          NaN       NaN  ...
# 3            NaN                NaN           NaN          NaN       NaN  ...
# 4            NaN                NaN           NaN          NaN       NaN  ...
#
#    sex_partners_score  get_along_well_with_family_score  \
# 0                 NaN                               NaN
# 1                 NaN                               NaN
# 2                 NaN                               NaN
# 3                 NaN                               NaN
# 4                 NaN                               NaN
#
#    political_tolerance_score ethnicity_importance_score  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#   religion_importance_score politics_importance_score  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    num_children_wanted_score  already_has_kids  casual_sex_score  \
# 0                        NaN               NaN               NaN
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               NaN
# 3                        NaN               NaN               NaN
# 4                        NaN               NaN               NaN
#
#    hard_work_and_success_belief_score
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 31 columns]

# %%
user_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2553 entries, 0 to 2552
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   user_id                             2553 non-null   object
#  1   age                                 2553 non-null   int64
#  2   gender                              2553 non-null   object
#  3   attracted_to                        2553 non-null   object
#  4   iq_share_correct                    853 non-null    float64
#  5   agreeableness                       853 non-null    float64
#  6   conscientiousness                   853 non-null    float64
#  7   extraversion                        853 non-null    float64
#  8   neuroticism                         853 non-null    float64
#  9   openness                            853 non-null    float64
#  10  avg_physical_attractiveness_rating  1026 non-null   float64
#  11  height_inches                       929 non-null    float64
#  12  income_bucket                       930 non-null    float64
#  13  ethnicity                           2553 non-null   object
#  14  religion                            2553 non-null   object
#  15  politics                            2553 non-null   object
#  16  nicotine_score                      945 non-null    float64
#  17  alcohol_score                       927 non-null    float64
#  18  marijuana_score                     919 non-null    float64
#  19  has_used_psychedelics               923 non-null    float64
#  20  behavioral_health_score             885 non-null    float64
#  21  sex_partners_score                  924 non-null    float64
#  22  get_along_well_with_family_score    882 non-null    float64
#  23  political_tolerance_score           884 non-null    float64
#  24  ethnicity_importance_score          939 non-null    float64
#  25  religion_importance_score           918 non-null    float64
#  26  politics_importance_score           933 non-null    float64
#  27  num_children_wanted_score           929 non-null    float64
#  28  already_has_kids                    922 non-null    float64
#  29  casual_sex_score                    936 non-null    float64
#  30  hard_work_and_success_belief_score  892 non-null    float64
# dtypes: float64(24), int64(1), object(6)
# memory usage: 618.4+ KB

# %% [markdown]
# ## Descriptive Statistics

# %%
user_features[:10]
# Out:
#                         user_id  age  gender attracted_to  iq_share_correct  \
# 0  N2QikIhXWyaoVSkD22KSatymXry1   33    male        women               NaN
# 1  a0qF436mgXPGArB23AD56eCA4CM2   33    male        women               NaN
# 2  8flwy3Pu0xdaJETKL7km2UfUTOh1   32    male        women               NaN
# 3  GD1gM3nQi0QKEukab2PNEQO2gvF2   30  female          men               NaN
# 4  rqVRyEhy97WenlbS8Vd0q6Fs6xf1   28  female          men               NaN
# 5  Ij7dYNQhSCP7ryOqaVYGxnv4ySO2   39  female          men               NaN
# 6  aut8WoVxHMYJg0Vv5ryCv1J60b73   38    male        women               0.8
# 7  PgiOt5izT1SLQSuOVAT0zWH0nmS2   28  female          men               NaN
# 8  94nqkaTOKacs0OoJ9XfabdKySBx1   29    male        women               NaN
# 9  LsT7uUqKijbNF4WMyvDeGSKTOHI3   39    male        women               NaN
#
#    agreeableness  conscientiousness  extraversion  neuroticism  openness  ...  \
# 0            NaN                NaN           NaN          NaN       NaN  ...
# 1            NaN                NaN           NaN          NaN       NaN  ...
# 2            NaN                NaN           NaN          NaN       NaN  ...
# 3            NaN                NaN           NaN          NaN       NaN  ...
# 4            NaN                NaN           NaN          NaN       NaN  ...
# 5            NaN                NaN           NaN          NaN       NaN  ...
# 6           41.0               37.0          40.0         16.0      30.0  ...
# 7            NaN                NaN           NaN          NaN       NaN  ...
# 8            NaN                NaN           NaN          NaN       NaN  ...
# 9            NaN                NaN           NaN          NaN       NaN  ...
#
#    sex_partners_score  get_along_well_with_family_score  \
# 0                 NaN                               NaN
# 1                 NaN                               NaN
# 2                 NaN                               NaN
# 3                 NaN                               NaN
# 4                 NaN                               NaN
# 5                 NaN                               NaN
# 6                 2.0                               1.0
# 7                 NaN                               NaN
# 8                 NaN                               NaN
# 9                 NaN                               NaN
#
#    political_tolerance_score ethnicity_importance_score  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 5                        NaN                        NaN
# 6                        3.0                        0.0
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                        NaN                        NaN
#
#   religion_importance_score politics_importance_score  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       0.0                       1.0
# 7                       NaN                       NaN
# 8                       NaN                       NaN
# 9                       NaN                       NaN
#
#    num_children_wanted_score  already_has_kids  casual_sex_score  \
# 0                        NaN               NaN               NaN
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               NaN
# 3                        NaN               NaN               NaN
# 4                        NaN               NaN               NaN
# 5                        NaN               NaN               NaN
# 6                        0.0               0.0               4.0
# 7                        NaN               NaN               NaN
# 8                        NaN               NaN               NaN
# 9                        NaN               NaN               NaN
#
#    hard_work_and_success_belief_score
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 3.0
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
#
# [10 rows x 31 columns]

# %%
user_features.describe().T
# Out:
#                                      count       mean       std        min  \
# age                                 2553.0  33.156678  6.667111  18.000000
# iq_share_correct                     853.0   0.698242  0.247835   0.000000
# agreeableness                        853.0  37.856975  3.245899  24.000000
# conscientiousness                    853.0  36.515826  4.718985  19.000000
# extraversion                         853.0  35.363423  4.632420  17.000000
# neuroticism                          853.0  20.131301  5.196524  12.000000
# openness                             853.0  27.194607  2.836651  16.000000
# avg_physical_attractiveness_rating  1026.0   4.564394  1.463143   1.285714
# height_inches                        929.0  67.223897  3.938568  55.000000
# income_bucket                        930.0   4.802151  1.886898   1.000000
# nicotine_score                       945.0   0.140741  0.347938   0.000000
# alcohol_score                        927.0   1.408846  0.713982   0.000000
# marijuana_score                      919.0   0.577802  0.930122   0.000000
# has_used_psychedelics                923.0   0.262189  0.440063   0.000000
# behavioral_health_score              885.0   2.676836  1.063363   0.000000
# sex_partners_score                   924.0   1.214286  0.989419   0.000000
# get_along_well_with_family_score     882.0   0.874150  0.331869   0.000000
# political_tolerance_score            884.0   2.738688  1.026620   0.000000
# ethnicity_importance_score           939.0   0.355698  0.618821   0.000000
# religion_importance_score            918.0   0.766885  0.735539   0.000000
# politics_importance_score            933.0   0.869239  0.701047   0.000000
# num_children_wanted_score            929.0   1.363832  0.876553   0.000000
# already_has_kids                     922.0   0.218004  0.413114   0.000000
# casual_sex_score                     936.0   1.852564  1.228735   0.000000
# hard_work_and_success_belief_score   892.0   3.091928  0.835829   0.000000
#
#                                           25%        50%        75%        max
# age                                 29.000000  32.000000  36.000000  81.000000
# iq_share_correct                     0.533333   0.733333   0.933333   1.000000
# agreeableness                       36.000000  39.000000  40.000000  42.000000
# conscientiousness                   34.000000  37.000000  40.000000  45.000000
# extraversion                        32.000000  36.000000  39.000000  42.000000
# neuroticism                         16.000000  20.000000  24.000000  36.000000
# openness                            26.000000  28.000000  30.000000  30.000000
# avg_physical_attractiveness_rating   3.462821   4.555556   5.625000   9.090909
# height_inches                       64.000000  67.000000  70.000000  80.000000
# income_bucket                        4.000000   5.000000   6.000000   9.000000
# nicotine_score                       0.000000   0.000000   0.000000   1.000000
# alcohol_score                        1.000000   1.000000   2.000000   3.000000
# marijuana_score                      0.000000   0.000000   1.000000   3.000000
# has_used_psychedelics                0.000000   0.000000   1.000000   1.000000
# behavioral_health_score              2.000000   3.000000   3.000000   4.000000
# sex_partners_score                   0.000000   1.000000   2.000000   4.000000
# get_along_well_with_family_score     1.000000   1.000000   1.000000   1.000000
# political_tolerance_score            2.000000   3.000000   3.000000   4.000000
# ethnicity_importance_score           0.000000   0.000000   1.000000   2.000000
# religion_importance_score            0.000000   1.000000   1.000000   2.000000
# politics_importance_score            0.000000   1.000000   1.000000   2.000000
# num_children_wanted_score            1.000000   2.000000   2.000000   3.000000
# already_has_kids                     0.000000   0.000000   0.000000   1.000000
# casual_sex_score                     1.000000   2.000000   3.000000   4.000000
# hard_work_and_success_belief_score   3.000000   3.000000   4.000000   4.000000

# %%
desc = pd.DataFrame(index=user_features.columns)
desc['count']  = user_features.count()
desc['nunique'] = user_features.nunique()
desc['% unique'] = 100* user_features.nunique()/user_features.count()
desc['null'] = user_features.isnull().sum()
desc['type'] = user_features.dtypes

# %%
desc
# Out:
#                                     count  nunique    % unique  null     type
# user_id                              2553     2553  100.000000     0   object
# age                                  2553       50    1.958480     0    int64
# gender                               2553        2    0.078339     0   object
# attracted_to                         2553        3    0.117509     0   object
# iq_share_correct                      853       16    1.875733  1700  float64
# agreeableness                         853       18    2.110199  1700  float64
# conscientiousness                     853       27    3.165299  1700  float64
# extraversion                          853       24    2.813599  1700  float64
# neuroticism                           853       24    2.813599  1700  float64
# openness                              853       15    1.758499  1700  float64
# avg_physical_attractiveness_rating   1026      411   40.058480  1527  float64
# height_inches                         929       26    2.798708  1624  float64
# income_bucket                         930        9    0.967742  1623  float64
# ethnicity                            2553        1    0.039170     0   object
# religion                             2553        1    0.039170     0   object
# politics                             2553        1    0.039170     0   object
# nicotine_score                        945        2    0.211640  1608  float64
# alcohol_score                         927        4    0.431499  1626  float64
# marijuana_score                       919        4    0.435256  1634  float64
# has_used_psychedelics                 923        2    0.216685  1630  float64
# behavioral_health_score               885        5    0.564972  1668  float64
# sex_partners_score                    924        5    0.541126  1629  float64
# get_along_well_with_family_score      882        2    0.226757  1671  float64
# political_tolerance_score             884        5    0.565611  1669  float64
# ethnicity_importance_score            939        3    0.319489  1614  float64
# religion_importance_score             918        3    0.326797  1635  float64
# politics_importance_score             933        3    0.321543  1620  float64
# num_children_wanted_score             929        4    0.430571  1624  float64
# already_has_kids                      922        2    0.216920  1631  float64
# casual_sex_score                      936        5    0.534188  1617  float64
# hard_work_and_success_belief_score    892        5    0.560538  1661  float64

# %% [markdown]
# ### The next cell contains the complete descriptive analysis. I will leave the prior code for better understanding of the process

# %%
pd.concat([desc,user_features.describe().T.drop('count',axis=1)],axis=1)
# Out:
#                                     count  nunique    % unique  null     type  \
# user_id                              2553     2553  100.000000     0   object
# age                                  2553       50    1.958480     0    int64
# gender                               2553        2    0.078339     0   object
# attracted_to                         2553        3    0.117509     0   object
# iq_share_correct                      853       16    1.875733  1700  float64
# agreeableness                         853       18    2.110199  1700  float64
# conscientiousness                     853       27    3.165299  1700  float64
# extraversion                          853       24    2.813599  1700  float64
# neuroticism                           853       24    2.813599  1700  float64
# openness                              853       15    1.758499  1700  float64
# avg_physical_attractiveness_rating   1026      411   40.058480  1527  float64
# height_inches                         929       26    2.798708  1624  float64
# income_bucket                         930        9    0.967742  1623  float64
# ethnicity                            2553        1    0.039170     0   object
# religion                             2553        1    0.039170     0   object
# politics                             2553        1    0.039170     0   object
# nicotine_score                        945        2    0.211640  1608  float64
# alcohol_score                         927        4    0.431499  1626  float64
# marijuana_score                       919        4    0.435256  1634  float64
# has_used_psychedelics                 923        2    0.216685  1630  float64
# behavioral_health_score               885        5    0.564972  1668  float64
# sex_partners_score                    924        5    0.541126  1629  float64
# get_along_well_with_family_score      882        2    0.226757  1671  float64
# political_tolerance_score             884        5    0.565611  1669  float64
# ethnicity_importance_score            939        3    0.319489  1614  float64
# religion_importance_score             918        3    0.326797  1635  float64
# politics_importance_score             933        3    0.321543  1620  float64
# num_children_wanted_score             929        4    0.430571  1624  float64
# already_has_kids                      922        2    0.216920  1631  float64
# casual_sex_score                      936        5    0.534188  1617  float64
# hard_work_and_success_belief_score    892        5    0.560538  1661  float64
#
#                                          mean       std        min        25%  \
# user_id                                   NaN       NaN        NaN        NaN
# age                                 33.156678  6.667111  18.000000  29.000000
# gender                                    NaN       NaN        NaN        NaN
# attracted_to                              NaN       NaN        NaN        NaN
# iq_share_correct                     0.698242  0.247835   0.000000   0.533333
# agreeableness                       37.856975  3.245899  24.000000  36.000000
# conscientiousness                   36.515826  4.718985  19.000000  34.000000
# extraversion                        35.363423  4.632420  17.000000  32.000000
# neuroticism                         20.131301  5.196524  12.000000  16.000000
# openness                            27.194607  2.836651  16.000000  26.000000
# avg_physical_attractiveness_rating   4.564394  1.463143   1.285714   3.462821
# height_inches                       67.223897  3.938568  55.000000  64.000000
# income_bucket                        4.802151  1.886898   1.000000   4.000000
# ethnicity                                 NaN       NaN        NaN        NaN
# religion                                  NaN       NaN        NaN        NaN
# politics                                  NaN       NaN        NaN        NaN
# nicotine_score                       0.140741  0.347938   0.000000   0.000000
# alcohol_score                        1.408846  0.713982   0.000000   1.000000
# marijuana_score                      0.577802  0.930122   0.000000   0.000000
# has_used_psychedelics                0.262189  0.440063   0.000000   0.000000
# behavioral_health_score              2.676836  1.063363   0.000000   2.000000
# sex_partners_score                   1.214286  0.989419   0.000000   0.000000
# get_along_well_with_family_score     0.874150  0.331869   0.000000   1.000000
# political_tolerance_score            2.738688  1.026620   0.000000   2.000000
# ethnicity_importance_score           0.355698  0.618821   0.000000   0.000000
# religion_importance_score            0.766885  0.735539   0.000000   0.000000
# politics_importance_score            0.869239  0.701047   0.000000   0.000000
# num_children_wanted_score            1.363832  0.876553   0.000000   1.000000
# already_has_kids                     0.218004  0.413114   0.000000   0.000000
# casual_sex_score                     1.852564  1.228735   0.000000   1.000000
# hard_work_and_success_belief_score   3.091928  0.835829   0.000000   3.000000
#
#                                           50%        75%        max
# user_id                                   NaN        NaN        NaN
# age                                 32.000000  36.000000  81.000000
# gender                                    NaN        NaN        NaN
# attracted_to                              NaN        NaN        NaN
# iq_share_correct                     0.733333   0.933333   1.000000
# agreeableness                       39.000000  40.000000  42.000000
# conscientiousness                   37.000000  40.000000  45.000000
# extraversion                        36.000000  39.000000  42.000000
# neuroticism                         20.000000  24.000000  36.000000
# openness                            28.000000  30.000000  30.000000
# avg_physical_attractiveness_rating   4.555556   5.625000   9.090909
# height_inches                       67.000000  70.000000  80.000000
# income_bucket                        5.000000   6.000000   9.000000
# ethnicity                                 NaN        NaN        NaN
# religion                                  NaN        NaN        NaN
# politics                                  NaN        NaN        NaN
# nicotine_score                       0.000000   0.000000   1.000000
# alcohol_score                        1.000000   2.000000   3.000000
# marijuana_score                      0.000000   1.000000   3.000000
# has_used_psychedelics                0.000000   1.000000   1.000000
# behavioral_health_score              3.000000   3.000000   4.000000
# sex_partners_score                   1.000000   2.000000   4.000000
# get_along_well_with_family_score     1.000000   1.000000   1.000000
# political_tolerance_score            3.000000   3.000000   4.000000
# ethnicity_importance_score           0.000000   1.000000   2.000000
# religion_importance_score            1.000000   1.000000   2.000000
# politics_importance_score            1.000000   1.000000   2.000000
# num_children_wanted_score            2.000000   2.000000   3.000000
# already_has_kids                     0.000000   0.000000   1.000000
# casual_sex_score                     2.000000   3.000000   4.000000
# hard_work_and_success_belief_score   3.000000   4.000000   4.000000

# %% [markdown]
# ## CLEANING THE DATA

# %% [markdown]
# ### We first need to do some data cleaning. There are three features with censored data

# %%
user_features['ethnicity'].unique()
# Out:
# array(['censored'], dtype=object)

# %%
user_features['religion'].unique()
# Out:
# array(['censored'], dtype=object)

# %%
user_features['politics'].unique()
# Out:
# array(['censored'], dtype=object)

# %%
user_features = user_features.drop(['ethnicity','religion','politics'], axis=1)

# %% [markdown]
# We drop those three columns

# %%
user_features.head()
# Out:
#                         user_id  age  gender attracted_to  iq_share_correct  \
# 0  N2QikIhXWyaoVSkD22KSatymXry1   33    male        women               NaN
# 1  a0qF436mgXPGArB23AD56eCA4CM2   33    male        women               NaN
# 2  8flwy3Pu0xdaJETKL7km2UfUTOh1   32    male        women               NaN
# 3  GD1gM3nQi0QKEukab2PNEQO2gvF2   30  female          men               NaN
# 4  rqVRyEhy97WenlbS8Vd0q6Fs6xf1   28  female          men               NaN
#
#    agreeableness  conscientiousness  extraversion  neuroticism  openness  ...  \
# 0            NaN                NaN           NaN          NaN       NaN  ...
# 1            NaN                NaN           NaN          NaN       NaN  ...
# 2            NaN                NaN           NaN          NaN       NaN  ...
# 3            NaN                NaN           NaN          NaN       NaN  ...
# 4            NaN                NaN           NaN          NaN       NaN  ...
#
#    sex_partners_score  get_along_well_with_family_score  \
# 0                 NaN                               NaN
# 1                 NaN                               NaN
# 2                 NaN                               NaN
# 3                 NaN                               NaN
# 4                 NaN                               NaN
#
#    political_tolerance_score  ethnicity_importance_score  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    religion_importance_score  politics_importance_score  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    num_children_wanted_score  already_has_kids  casual_sex_score  \
# 0                        NaN               NaN               NaN
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               NaN
# 3                        NaN               NaN               NaN
# 4                        NaN               NaN               NaN
#
#    hard_work_and_success_belief_score
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# #### It looks like we are going to work with many null values. In some cases we have over 66% of null data...

# %% [markdown]
# ### Let's now visualize all the missing data

# %%
def percent_missing(df):
    percent_nan = 100 * df.isnull().sum() / len(df)
    percent_nan = percent_nan[percent_nan > 0].sort_values()
    
    return percent_nan

# %%
percent_nan = percent_missing(user_features)

# %%
percent_nan
# Out:
# avg_physical_attractiveness_rating    59.811986
# nicotine_score                        62.984724
# ethnicity_importance_score            63.219741
# casual_sex_score                      63.337250
# politics_importance_score             63.454759
# income_bucket                         63.572268
# num_children_wanted_score             63.611438
# height_inches                         63.611438
# alcohol_score                         63.689777
# sex_partners_score                    63.807286
# has_used_psychedelics                 63.846455
# already_has_kids                      63.885625
# marijuana_score                       64.003134
# religion_importance_score             64.042303
# hard_work_and_success_belief_score    65.060713
# behavioral_health_score               65.334900
# political_tolerance_score             65.374070
# get_along_well_with_family_score      65.452409
# openness                              66.588327
# neuroticism                           66.588327
# extraversion                          66.588327
# conscientiousness                     66.588327
# agreeableness                         66.588327
# iq_share_correct                      66.588327
# dtype: float64

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation=90)
plt.ylim(0,100);

# %% [markdown]
# #### Probably all the missing data is coming mostly from the same rows...

# %% [markdown]
# ### Let's drop the rows with null values on our most missing values feature (iq_share_correct).
# ### We are dropping > 66% of rows. We will assume the missing values are normally distributed. If that was not the case, we would be skewing the sample.

# %%
user_features[user_features['iq_share_correct'].isnull()]
# Out:
#                            user_id  age  gender attracted_to  \
# 0     N2QikIhXWyaoVSkD22KSatymXry1   33    male        women
# 1     a0qF436mgXPGArB23AD56eCA4CM2   33    male        women
# 2     8flwy3Pu0xdaJETKL7km2UfUTOh1   32    male        women
# 3     GD1gM3nQi0QKEukab2PNEQO2gvF2   30  female          men
# 4     rqVRyEhy97WenlbS8Vd0q6Fs6xf1   28  female          men
# ...                            ...  ...     ...          ...
# 2521  twYBEtXUIZVDDPO27cjswSewGRi2   33  female          men
# 2524  IUaVRpsCQeUqdcWLQt1b6f2OMjF2   27    male        women
# 2530  3IZMT15cMuU4EpKXsuQsYhiAcmB2   28  female          men
# 2534  qvFUfK7b9nTyoPq6ShoHlnNIH9u1   31  female          men
# 2548  gTZNl0LPxmchsBpK5YjZCxgzYm63   36  female          men
#
#       iq_share_correct  agreeableness  conscientiousness  extraversion  \
# 0                  NaN            NaN                NaN           NaN
# 1                  NaN            NaN                NaN           NaN
# 2                  NaN            NaN                NaN           NaN
# 3                  NaN            NaN                NaN           NaN
# 4                  NaN            NaN                NaN           NaN
# ...                ...            ...                ...           ...
# 2521               NaN            NaN                NaN           NaN
# 2524               NaN            NaN                NaN           NaN
# 2530               NaN            NaN                NaN           NaN
# 2534               NaN            NaN                NaN           NaN
# 2548               NaN            NaN                NaN           NaN
#
#       neuroticism  openness  ...  sex_partners_score  \
# 0             NaN       NaN  ...                 NaN
# 1             NaN       NaN  ...                 NaN
# 2             NaN       NaN  ...                 NaN
# 3             NaN       NaN  ...                 NaN
# 4             NaN       NaN  ...                 NaN
# ...           ...       ...  ...                 ...
# 2521          NaN       NaN  ...                 NaN
# 2524          NaN       NaN  ...                 1.0
# 2530          NaN       NaN  ...                 NaN
# 2534          NaN       NaN  ...                 NaN
# 2548          NaN       NaN  ...                 NaN
#
#       get_along_well_with_family_score  political_tolerance_score  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                  NaN                        NaN
# 4                                  NaN                        NaN
# ...                                ...                        ...
# 2521                               NaN                        NaN
# 2524                               0.0                        NaN
# 2530                               NaN                        NaN
# 2534                               NaN                        NaN
# 2548                               NaN                        NaN
#
#       ethnicity_importance_score  religion_importance_score  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 2521                         NaN                        NaN
# 2524                         0.0                        0.0
# 2530                         NaN                        NaN
# 2534                         NaN                        0.0
# 2548                         NaN                        NaN
#
#       politics_importance_score  num_children_wanted_score  already_has_kids  \
# 0                           NaN                        NaN               NaN
# 1                           NaN                        NaN               NaN
# 2                           NaN                        NaN               NaN
# 3                           NaN                        NaN               NaN
# 4                           NaN                        NaN               NaN
# ...                         ...                        ...               ...
# 2521                        NaN                        NaN               NaN
# 2524                        0.0                        NaN               NaN
# 2530                        NaN                        NaN               NaN
# 2534                        NaN                        NaN               NaN
# 2548                        NaN                        NaN               NaN
#
#       casual_sex_score  hard_work_and_success_belief_score
# 0                  NaN                                 NaN
# 1                  NaN                                 NaN
# 2                  NaN                                 NaN
# 3                  NaN                                 NaN
# 4                  NaN                                 NaN
# ...                ...                                 ...
# 2521               NaN                                 NaN
# 2524               NaN                                 3.0
# 2530               NaN                                 NaN
# 2534               NaN                                 NaN
# 2548               NaN                                 NaN
#
# [1700 rows x 28 columns]

# %%
user_features = user_features[user_features['iq_share_correct'].notnull()]

# %% [markdown]
# Let's see now how many missing values we have

# %%
percent_nan = percent_missing(user_features)

# %%
percent_nan
# Out:
# has_used_psychedelics                  0.117233
# agreeableness                          0.351700
# conscientiousness                      0.351700
# extraversion                           0.351700
# neuroticism                            0.351700
# openness                               0.351700
# behavioral_health_score                3.868699
# get_along_well_with_family_score       3.868699
# hard_work_and_success_belief_score     3.868699
# political_tolerance_score              3.985932
# avg_physical_attractiveness_rating    30.949590
# dtype: float64

# %% [markdown]
# ### We cut out most of our missing values. But we still have more work to do.

# %% [markdown]
# We have to decide what to do with all the avg_physical_attractiveness_rating missing values. Since the average physical attractiveness is one of the most important features of this dataset, we will avoid dropping it unless it leaves us with no other option.

# %%
#Let's explore how to choose to remove or fill in missing data for rows that are missing some data. 
#Let's choose some threshold where we decide it is ok to drop a row if its missing some data
#(instead of attempting to fill in that missing data point). We will choose 1% as our threshold. 
#This means if less than 1% of the rows are missing this feature, we will consider just dropping that row, 
#instead of dealing with the feature itself. There is no right answer here,
#just use common sense and your domain knowledge of the dataset, obviously you don't want
#to drop a very high threshold like 50% , you should also explore correlation to the dataset, 
#maybe it makes sense to drop the feature instead.

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation=90)
plt.ylim(0,40);

# %%
user_features[user_features['avg_physical_attractiveness_rating'].isnull()]
# Out:
#                            user_id  age  gender attracted_to  \
# 13    fiju3kSbpbNK9ViarTBsbgXjlG53   25  female          men
# 56    j4NdgVLSXZVYiKTCC4bYJITnDOK2   32  female          men
# 86    Y8qLwXznNQcQneYhtFnN4pP8F2P2   39  female          men
# 130   F8oH9T8qTaWOIgDwngok1ORNhgB2   26    male        women
# 171   DB0MO5H2KrTeaRUPlI7tMRrWwpf1   30  female          men
# ...                            ...  ...     ...          ...
# 2501  sINqjwXmXdSOobbiR7KaiQurZt23   38    male        women
# 2520  I4nHNr9ofHQdxFscE8QKlQ0v5M52   31    male        women
# 2532  FeRP2odmWpSggaV0mZltAX8v0s52   34    male        women
# 2537  Ob6gU61BlQUe0OkElSFgsBMRCIx1   32    male        women
# 2539  9J5iGWLJ7wSiI4SSLkuMve8dUlJ2   38    male        women
#
#       iq_share_correct  agreeableness  conscientiousness  extraversion  \
# 13            1.000000           35.0               34.0          33.0
# 56            0.733333           40.0               42.0          41.0
# 86            0.866667           40.0               34.0          38.0
# 130           0.933333           41.0               33.0          36.0
# 171           0.733333           42.0               32.0          23.0
# ...                ...            ...                ...           ...
# 2501          0.866667           30.0               28.0          40.0
# 2520          0.333333           40.0               39.0          41.0
# 2532          0.866667           41.0               39.0          40.0
# 2537          0.733333           42.0               39.0          35.0
# 2539          0.866667           37.0               32.0          42.0
#
#       neuroticism  openness  ...  sex_partners_score  \
# 13           26.0      30.0  ...                 0.0
# 56           24.0      29.0  ...                 2.0
# 86           21.0      30.0  ...                 2.0
# 130          30.0      30.0  ...                 0.0
# 171          26.0      28.0  ...                 0.0
# ...           ...       ...  ...                 ...
# 2501         25.0      23.0  ...                 1.0
# 2520         22.0      30.0  ...                 1.0
# 2532         12.0      29.0  ...                 1.0
# 2537         15.0      29.0  ...                 1.0
# 2539         16.0      30.0  ...                 2.0
#
#       get_along_well_with_family_score  political_tolerance_score  \
# 13                                 1.0                        0.0
# 56                                 1.0                        3.0
# 86                                 1.0                        3.0
# 130                                1.0                        1.0
# 171                                1.0                        1.0
# ...                                ...                        ...
# 2501                               1.0                        3.0
# 2520                               1.0                        3.0
# 2532                               1.0                        3.0
# 2537                               1.0                        3.0
# 2539                               1.0                        4.0
#
#       ethnicity_importance_score  religion_importance_score  \
# 13                           0.0                        1.0
# 56                           0.0                        1.0
# 86                           0.0                        0.0
# 130                          0.0                        0.0
# 171                          0.0                        1.0
# ...                          ...                        ...
# 2501                         1.0                        0.0
# 2520                         0.0                        0.0
# 2532                         0.0                        0.0
# 2537                         0.0                        0.0
# 2539                         0.0                        0.0
#
#       politics_importance_score  num_children_wanted_score  already_has_kids  \
# 13                          2.0                        0.0               0.0
# 56                          2.0                        2.0               0.0
# 86                          1.0                        1.0               0.0
# 130                         1.0                        2.0               0.0
# 171                         1.0                        1.0               0.0
# ...                         ...                        ...               ...
# 2501                        1.0                        0.0               0.0
# 2520                        0.0                        0.0               0.0
# 2532                        1.0                        2.0               0.0
# 2537                        0.0                        1.0               0.0
# 2539                        0.0                        2.0               0.0
#
#       casual_sex_score  hard_work_and_success_belief_score
# 13                 2.0                                 3.0
# 56                 2.0                                 3.0
# 86                 2.0                                 2.0
# 130                1.0                                 3.0
# 171                0.0                                 3.0
# ...                ...                                 ...
# 2501               3.0                                 2.0
# 2520               3.0                                 4.0
# 2532               2.0                                 4.0
# 2537               2.0                                 3.0
# 2539               3.0                                 3.0
#
# [264 rows x 28 columns]

# %%
user_features = user_features[user_features['avg_physical_attractiveness_rating'].notnull()]

# %%
len(user_features)
# Out:
# 589

# %% [markdown]
# Let's check again the null values

# %%
percent_nan = percent_missing(user_features)

# %%
percent_nan
# Out:
# agreeableness                         0.169779
# conscientiousness                     0.169779
# extraversion                          0.169779
# neuroticism                           0.169779
# openness                              0.169779
# has_used_psychedelics                 0.169779
# behavioral_health_score               3.904924
# get_along_well_with_family_score      3.904924
# political_tolerance_score             3.904924
# hard_work_and_success_belief_score    3.904924
# dtype: float64

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation=90)
plt.ylim(0,4);

# %% [markdown]
# Let's drop those rows containing the 4% missing values

# %%
user_features = user_features[user_features['hard_work_and_success_belief_score'].notnull()]

# %%
user_features.isnull().sum()
# Out:
# user_id                               0
# age                                   0
# gender                                0
# attracted_to                          0
# iq_share_correct                      0
# agreeableness                         0
# conscientiousness                     0
# extraversion                          0
# neuroticism                           0
# openness                              0
# avg_physical_attractiveness_rating    0
# height_inches                         0
# income_bucket                         0
# nicotine_score                        0
# alcohol_score                         0
# marijuana_score                       0
# has_used_psychedelics                 0
# behavioral_health_score               0
# sex_partners_score                    0
# get_along_well_with_family_score      0
# political_tolerance_score             0
# ethnicity_importance_score            0
# religion_importance_score             0
# politics_importance_score             0
# num_children_wanted_score             0
# already_has_kids                      0
# casual_sex_score                      0
# hard_work_and_success_belief_score    0
# dtype: int64

# %%
len(user_features)
# Out:
# 566

# %% [markdown]
# We have no more missing data and our dataset contains 566 rows

# %%
user_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 566 entries, 6 to 2552
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   user_id                             566 non-null    object
#  1   age                                 566 non-null    int64
#  2   gender                              566 non-null    object
#  3   attracted_to                        566 non-null    object
#  4   iq_share_correct                    566 non-null    float64
#  5   agreeableness                       566 non-null    float64
#  6   conscientiousness                   566 non-null    float64
#  7   extraversion                        566 non-null    float64
#  8   neuroticism                         566 non-null    float64
#  9   openness                            566 non-null    float64
#  10  avg_physical_attractiveness_rating  566 non-null    float64
#  11  height_inches                       566 non-null    float64
#  12  income_bucket                       566 non-null    float64
#  13  nicotine_score                      566 non-null    float64
#  14  alcohol_score                       566 non-null    float64
#  15  marijuana_score                     566 non-null    float64
#  16  has_used_psychedelics               566 non-null    float64
#  17  behavioral_health_score             566 non-null    float64
#  18  sex_partners_score                  566 non-null    float64
#  19  get_along_well_with_family_score    566 non-null    float64
#  20  political_tolerance_score           566 non-null    float64
#  21  ethnicity_importance_score          566 non-null    float64
#  22  religion_importance_score           566 non-null    float64
#  23  politics_importance_score           566 non-null    float64
#  24  num_children_wanted_score           566 non-null    float64
#  25  already_has_kids                    566 non-null    float64
#  26  casual_sex_score                    566 non-null    float64
#  27  hard_work_and_success_belief_score  566 non-null    float64
# dtypes: float64(24), int64(1), object(3)
# memory usage: 128.2+ KB

# %% [markdown]
# ## Visualization of Distributions

# %%
user_features.columns
# Out:
# Index(['user_id', 'age', 'gender', 'attracted_to', 'iq_share_correct',
#        'agreeableness', 'conscientiousness', 'extraversion', 'neuroticism',
#        'openness', 'avg_physical_attractiveness_rating', 'height_inches',
#        'income_bucket', 'nicotine_score', 'alcohol_score', 'marijuana_score',
#        'has_used_psychedelics', 'behavioral_health_score',
#        'sex_partners_score', 'get_along_well_with_family_score',
#        'political_tolerance_score', 'ethnicity_importance_score',
#        'religion_importance_score', 'politics_importance_score',
#        'num_children_wanted_score', 'already_has_kids', 'casual_sex_score',
#        'hard_work_and_success_belief_score'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10),dpi=200)
sns.kdeplot(data = user_features, x='age',fill=True,)
plt.xlabel("Age")
plt.ylabel("Density")
plt.title('Age Distribution',fontsize =24,fontweight = 'bold')

plt.show()

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.kdeplot(data = user_features, x='iq_share_correct',fill=True,)
plt.xlabel("iq_share_correct")
plt.ylabel("Density")
plt.title('IQ Distribution',fontsize =24,fontweight = 'bold')

plt.show()

# %%
# TENGO QUE CAPAR EL 0 Y EL 1

# %%
plt.figure(figsize=(20,10),dpi=200)
sns.kdeplot(data = user_features,hue='gender', x='avg_physical_attractiveness_rating',fill=True,)
plt.xlabel("attractiveness")
plt.ylabel("Density")
plt.title('Attractiveness Distribution',fontsize =24,fontweight = 'bold')

plt.show()

# %% [markdown]
# As we already know, females rate males below average, while males rate females really accurately (really close to a normal distribution)

# %% [markdown]
# ### Let's see some fun correlations

# %% [markdown]
# ## Data Visualization and Correlation Ideas:
#
# #### 1. Correlation Matrix
#
# #### 2. Outcomes Distribution
#
# #### 3. Physical Attractiveness vs. Likability
#
# #### 4. IQ vs. Likability
#
# #### 5. Personality Traits vs. Likability
#
# #### 6. Income vs. Likability
#
# #### 7. Drug Use vs. Likability
#
# #### 8. Height vs. Likability
#
# #### 9. Values/Importance Scores vs. Likability
#
# #### 10. Number of Children Wanted vs. Likability

# %% [markdown]
# #### 1. Correlation Matrix:
#    Investigate correlations between various attributes. For instance, are there correlations between personality traits (Big 5) and the outcomes of dates (likeability, mutual interest)?

# %%
correlation_matrix = user_features.corr(numeric_only=True)
correlation_matrix
# Out:
#                                          age  iq_share_correct  agreeableness  \
# age                                 1.000000          0.070302       0.019123
# iq_share_correct                    0.070302          1.000000       0.252905
# agreeableness                       0.019123          0.252905       1.000000
# conscientiousness                   0.098454         -0.000188       0.149175
# extraversion                        0.090454          0.082451       0.047317
# neuroticism                        -0.156413         -0.098285      -0.159181
# openness                            0.036642          0.256515       0.220460
# avg_physical_attractiveness_rating -0.138004          0.130435       0.072965
# height_inches                       0.073210         -0.028532      -0.185681
# income_bucket                       0.267984          0.247460      -0.037160
# nicotine_score                      0.020051         -0.060783      -0.125687
# alcohol_score                       0.037867          0.059842      -0.045820
# marijuana_score                    -0.035155         -0.055573      -0.068543
# has_used_psychedelics              -0.010263          0.087672      -0.081008
# behavioral_health_score             0.066162          0.088619      -0.020899
# sex_partners_score                  0.008942         -0.027680      -0.093199
# get_along_well_with_family_score   -0.011936          0.119748       0.231899
# political_tolerance_score           0.067135         -0.075330      -0.033850
# ethnicity_importance_score          0.024774         -0.182238      -0.081981
# religion_importance_score           0.012513          0.026814       0.038656
# politics_importance_score          -0.042377          0.237832       0.045696
# num_children_wanted_score          -0.188491          0.015303      -0.037669
# already_has_kids                    0.333199         -0.159363       0.026820
# casual_sex_score                    0.095063          0.084079      -0.186148
# hard_work_and_success_belief_score -0.047445         -0.080336      -0.040965
#
#                                     conscientiousness  extraversion  \
# age                                          0.098454      0.090454
# iq_share_correct                            -0.000188      0.082451
# agreeableness                                0.149175      0.047317
# conscientiousness                            1.000000      0.225811
# extraversion                                 0.225811      1.000000
# neuroticism                                 -0.147044     -0.280917
# openness                                     0.137490      0.403582
# avg_physical_attractiveness_rating           0.037570      0.162945
# height_inches                               -0.030877     -0.036342
# income_bucket                                0.048566      0.158552
# nicotine_score                              -0.074381     -0.000809
# alcohol_score                               -0.052763      0.149015
# marijuana_score                             -0.117227      0.046486
# has_used_psychedelics                       -0.086527      0.054613
# behavioral_health_score                      0.150082      0.134529
# sex_partners_score                           0.021377      0.164446
# get_along_well_with_family_score             0.138422      0.228839
# political_tolerance_score                    0.010397      0.100282
# ethnicity_importance_score                   0.076099     -0.054964
# religion_importance_score                    0.099560     -0.055835
# politics_importance_score                    0.006476     -0.046830
# num_children_wanted_score                    0.026697      0.010929
# already_has_kids                             0.157577      0.134535
# casual_sex_score                            -0.097334      0.067056
# hard_work_and_success_belief_score           0.200047      0.100496
#
#                                     neuroticism  openness  \
# age                                   -0.156413  0.036642
# iq_share_correct                      -0.098285  0.256515
# agreeableness                         -0.159181  0.220460
# conscientiousness                     -0.147044  0.137490
# extraversion                          -0.280917  0.403582
# neuroticism                            1.000000 -0.238887
# openness                              -0.238887  1.000000
# avg_physical_attractiveness_rating    -0.068476  0.109563
# height_inches                         -0.187304 -0.019779
# income_bucket                         -0.135098  0.142892
# nicotine_score                         0.006280 -0.028654
# alcohol_score                         -0.029291  0.104889
# marijuana_score                        0.078086  0.072372
# has_used_psychedelics                 -0.031297  0.089388
# behavioral_health_score               -0.240655  0.078470
# sex_partners_score                    -0.076976  0.036673
# get_along_well_with_family_score      -0.179765  0.172171
# political_tolerance_score             -0.149796  0.057258
# ethnicity_importance_score             0.061042 -0.093965
# religion_importance_score              0.115938 -0.022101
# politics_importance_score              0.228365  0.060534
# num_children_wanted_score             -0.118105  0.063425
# already_has_kids                      -0.103670  0.000224
# casual_sex_score                      -0.044617  0.013553
# hard_work_and_success_belief_score    -0.069907  0.079361
#
#                                     avg_physical_attractiveness_rating  \
# age                                                          -0.138004
# iq_share_correct                                              0.130435
# agreeableness                                                 0.072965
# conscientiousness                                             0.037570
# extraversion                                                  0.162945
# neuroticism                                                  -0.068476
# openness                                                      0.109563
# avg_physical_attractiveness_rating                            1.000000
# height_inches                                                -0.126752
# income_bucket                                                 0.172588
# nicotine_score                                               -0.061519
# alcohol_score                                                 0.148367
# marijuana_score                                               0.008696
# has_used_psychedelics                                         0.031470
# behavioral_health_score                                       0.257761
# sex_partners_score                                            0.167534
# get_along_well_with_family_score                              0.125621
# political_tolerance_score                                     0.038262
# ethnicity_importance_score                                   -0.025306
# religion_importance_score                                     0.013246
# politics_importance_score                                     0.041369
# num_children_wanted_score                                     0.104950
# already_has_kids                                              0.028066
# casual_sex_score                                              0.039004
# hard_work_and_success_belief_score                            0.054357
#
#                                     height_inches  income_bucket  ...  \
# age                                      0.073210       0.267984  ...
# iq_share_correct                        -0.028532       0.247460  ...
# agreeableness                           -0.185681      -0.037160  ...
# conscientiousness                       -0.030877       0.048566  ...
# extraversion                            -0.036342       0.158552  ...
# neuroticism                             -0.187304      -0.135098  ...
# openness                                -0.019779       0.142892  ...
# avg_physical_attractiveness_rating      -0.126752       0.172588  ...
# height_inches                            1.000000       0.083240  ...
# income_bucket                            0.083240       1.000000  ...
# nicotine_score                           0.032479      -0.103171  ...
# alcohol_score                            0.008344       0.230635  ...
# marijuana_score                          0.052699      -0.025374  ...
# has_used_psychedelics                    0.108318       0.021307  ...
# behavioral_health_score                  0.215702       0.216110  ...
# sex_partners_score                       0.065510       0.135160  ...
# get_along_well_with_family_score        -0.025076       0.149590  ...
# political_tolerance_score                0.113970       0.138249  ...
# ethnicity_importance_score              -0.044079      -0.086495  ...
# religion_importance_score               -0.115696      -0.084179  ...
# politics_importance_score               -0.136900      -0.055985  ...
# num_children_wanted_score               -0.051212      -0.002512  ...
# already_has_kids                        -0.015881       0.082618  ...
# casual_sex_score                         0.238916       0.182046  ...
# hard_work_and_success_belief_score       0.020901       0.091366  ...
#
#                                     sex_partners_score  \
# age                                           0.008942
# iq_share_correct                             -0.027680
# agreeableness                                -0.093199
# conscientiousness                             0.021377
# extraversion                                  0.164446
# neuroticism                                  -0.076976
# openness                                      0.036673
# avg_physical_attractiveness_rating            0.167534
# height_inches                                 0.065510
# income_bucket                                 0.135160
# nicotine_score                                0.069460
# alcohol_score                                 0.212991
# marijuana_score                               0.114690
# has_used_psychedelics                         0.194927
# behavioral_health_score                       0.048678
# sex_partners_score                            1.000000
# get_along_well_with_family_score              0.015915
# political_tolerance_score                     0.001495
# ethnicity_importance_score                   -0.021145
# religion_importance_score                    -0.152202
# politics_importance_score                    -0.041285
# num_children_wanted_score                    -0.092780
# already_has_kids                              0.148549
# casual_sex_score                              0.313068
# hard_work_and_success_belief_score            0.043989
#
#                                     get_along_well_with_family_score  \
# age                                                        -0.011936
# iq_share_correct                                            0.119748
# agreeableness                                               0.231899
# conscientiousness                                           0.138422
# extraversion                                                0.228839
# neuroticism                                                -0.179765
# openness                                                    0.172171
# avg_physical_attractiveness_rating                          0.125621
# height_inches                                              -0.025076
# income_bucket                                               0.149590
# nicotine_score                                             -0.088392
# alcohol_score                                               0.061651
# marijuana_score                                            -0.049088
# has_used_psychedelics                                       0.010814
# behavioral_health_score                                     0.094927
# sex_partners_score                                          0.015915
# get_along_well_with_family_score                            1.000000
# political_tolerance_score                                   0.053173
# ethnicity_importance_score                                 -0.078230
# religion_importance_score                                  -0.045385
# politics_importance_score                                  -0.028644
# num_children_wanted_score                                   0.106769
# already_has_kids                                           -0.056825
# casual_sex_score                                            0.021278
# hard_work_and_success_belief_score                          0.143591
#
#                                     political_tolerance_score  \
# age                                                  0.067135
# iq_share_correct                                    -0.075330
# agreeableness                                       -0.033850
# conscientiousness                                    0.010397
# extraversion                                         0.100282
# neuroticism                                         -0.149796
# openness                                             0.057258
# avg_physical_attractiveness_rating                   0.038262
# height_inches                                        0.113970
# income_bucket                                        0.138249
# nicotine_score                                       0.050167
# alcohol_score                                        0.035098
# marijuana_score                                      0.026541
# has_used_psychedelics                                0.127518
# behavioral_health_score                              0.121732
# sex_partners_score                                   0.001495
# get_along_well_with_family_score                     0.053173
# political_tolerance_score                            1.000000
# ethnicity_importance_score                          -0.044508
# religion_importance_score                           -0.134218
# politics_importance_score                           -0.445445
# num_children_wanted_score                            0.009758
# already_has_kids                                     0.143888
# casual_sex_score                                     0.061878
# hard_work_and_success_belief_score                   0.152975
#
#                                     ethnicity_importance_score  \
# age                                                   0.024774
# iq_share_correct                                     -0.182238
# agreeableness                                        -0.081981
# conscientiousness                                     0.076099
# extraversion                                         -0.054964
# neuroticism                                           0.061042
# openness                                             -0.093965
# avg_physical_attractiveness_rating                   -0.025306
# height_inches                                        -0.044079
# income_bucket                                        -0.086495
# nicotine_score                                        0.054408
# alcohol_score                                        -0.018753
# marijuana_score                                       0.004903
# has_used_psychedelics                                -0.141888
# behavioral_health_score                              -0.055104
# sex_partners_score                                   -0.021145
# get_along_well_with_family_score                     -0.078230
# political_tolerance_score                            -0.044508
# ethnicity_importance_score                            1.000000
# religion_importance_score                             0.188655
# politics_importance_score                             0.090068
# num_children_wanted_score                             0.047072
# already_has_kids                                      0.108479
# casual_sex_score                                     -0.124111
# hard_work_and_success_belief_score                    0.061830
#
#                                     religion_importance_score  \
# age                                                  0.012513
# iq_share_correct                                     0.026814
# agreeableness                                        0.038656
# conscientiousness                                    0.099560
# extraversion                                        -0.055835
# neuroticism                                          0.115938
# openness                                            -0.022101
# avg_physical_attractiveness_rating                   0.013246
# height_inches                                       -0.115696
# income_bucket                                       -0.084179
# nicotine_score                                      -0.059956
# alcohol_score                                       -0.036873
# marijuana_score                                     -0.086696
# has_used_psychedelics                               -0.144693
# behavioral_health_score                             -0.066846
# sex_partners_score                                  -0.152202
# get_along_well_with_family_score                    -0.045385
# political_tolerance_score                           -0.134218
# ethnicity_importance_score                           0.188655
# religion_importance_score                            1.000000
# politics_importance_score                            0.365048
# num_children_wanted_score                            0.189024
# already_has_kids                                    -0.038378
# casual_sex_score                                    -0.398678
# hard_work_and_success_belief_score                   0.022443
#
#                                     politics_importance_score  \
# age                                                 -0.042377
# iq_share_correct                                     0.237832
# agreeableness                                        0.045696
# conscientiousness                                    0.006476
# extraversion                                        -0.046830
# neuroticism                                          0.228365
# openness                                             0.060534
# avg_physical_attractiveness_rating                   0.041369
# height_inches                                       -0.136900
# income_bucket                                       -0.055985
# nicotine_score                                      -0.075121
# alcohol_score                                       -0.001926
# marijuana_score                                      0.041233
# has_used_psychedelics                               -0.031744
# behavioral_health_score                             -0.084593
# sex_partners_score                                  -0.041285
# get_along_well_with_family_score                    -0.028644
# political_tolerance_score                           -0.445445
# ethnicity_importance_score                           0.090068
# religion_importance_score                            0.365048
# politics_importance_score                            1.000000
# num_children_wanted_score                            0.050276
# already_has_kids                                    -0.173626
# casual_sex_score                                    -0.089734
# hard_work_and_success_belief_score                  -0.073547
#
#                                     num_children_wanted_score  \
# age                                                 -0.188491
# iq_share_correct                                     0.015303
# agreeableness                                       -0.037669
# conscientiousness                                    0.026697
# extraversion                                         0.010929
# neuroticism                                         -0.118105
# openness                                             0.063425
# avg_physical_attractiveness_rating                   0.104950
# height_inches                                       -0.051212
# income_bucket                                       -0.002512
# nicotine_score                                      -0.060480
# alcohol_score                                       -0.004476
# marijuana_score                                     -0.055747
# has_used_psychedelics                               -0.046373
# behavioral_health_score                              0.059705
# sex_partners_score                                  -0.092780
# get_along_well_with_family_score                     0.106769
# political_tolerance_score                            0.009758
# ethnicity_importance_score                           0.047072
# religion_importance_score                            0.189024
# politics_importance_score                            0.050276
# num_children_wanted_score                            1.000000
# already_has_kids                                    -0.028234
# casual_sex_score                                    -0.170706
# hard_work_and_success_belief_score                   0.154610
#
#                                     already_has_kids  casual_sex_score  \
# age                                         0.333199          0.095063
# iq_share_correct                           -0.159363          0.084079
# agreeableness                               0.026820         -0.186148
# conscientiousness                           0.157577         -0.097334
# extraversion                                0.134535          0.067056
# neuroticism                                -0.103670         -0.044617
# openness                                    0.000224          0.013553
# avg_physical_attractiveness_rating          0.028066          0.039004
# height_inches                              -0.015881          0.238916
# income_bucket                               0.082618          0.182046
# nicotine_score                              0.031965          0.024014
# alcohol_score                              -0.019153          0.171394
# marijuana_score                            -0.026700          0.091315
# has_used_psychedelics                      -0.041328          0.170771
# behavioral_health_score                    -0.018031          0.056376
# sex_partners_score                          0.148549          0.313068
# get_along_well_with_family_score           -0.056825          0.021278
# political_tolerance_score                   0.143888          0.061878
# ethnicity_importance_score                  0.108479         -0.124111
# religion_importance_score                  -0.038378         -0.398678
# politics_importance_score                  -0.173626         -0.089734
# num_children_wanted_score                  -0.028234         -0.170706
# already_has_kids                            1.000000          0.008302
# casual_sex_score                            0.008302          1.000000
# hard_work_and_success_belief_score          0.047078         -0.047146
#
#                                     hard_work_and_success_belief_score
# age                                                          -0.047445
# iq_share_correct                                             -0.080336
# agreeableness                                                -0.040965
# conscientiousness                                             0.200047
# extraversion                                                  0.100496
# neuroticism                                                  -0.069907
# openness                                                      0.079361
# avg_physical_attractiveness_rating                            0.054357
# height_inches                                                 0.020901
# income_bucket                                                 0.091366
# nicotine_score                                                0.020571
# alcohol_score                                                -0.002721
# marijuana_score                                              -0.027751
# has_used_psychedelics                                        -0.039796
# behavioral_health_score                                       0.149915
# sex_partners_score                                            0.043989
# get_along_well_with_family_score                              0.143591
# political_tolerance_score                                     0.152975
# ethnicity_importance_score                                    0.061830
# religion_importance_score                                     0.022443
# politics_importance_score                                    -0.073547
# num_children_wanted_score                                     0.154610
# already_has_kids                                              0.047078
# casual_sex_score                                             -0.047146
# hard_work_and_success_belief_score                            1.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# ### Correlations Heatmap

# %%
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(user_features.corr(numeric_only=True), annot=True, fmt=".2f", linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ### Biggest correlations overall

# %%
big_corr = user_features.corr(numeric_only=True)[(user_features.corr(numeric_only=True) > 0.2) | (user_features.corr(numeric_only=True) < -0.2)]

f, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(big_corr, annot=True, fmt=".2f", linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %%
big_corr = big_corr[big_corr !=1]
round(big_corr.stack().drop_duplicates().sort_values(ascending=False),2)
# Out:
# marijuana_score                     has_used_psychedelics                 0.45
# extraversion                        openness                              0.40
# religion_importance_score           politics_importance_score             0.37
# age                                 already_has_kids                      0.33
# sex_partners_score                  casual_sex_score                      0.31
# age                                 income_bucket                         0.27
# avg_physical_attractiveness_rating  behavioral_health_score               0.26
# iq_share_correct                    openness                              0.26
#                                     agreeableness                         0.25
#                                     income_bucket                         0.25
# height_inches                       casual_sex_score                      0.24
# iq_share_correct                    politics_importance_score             0.24
# nicotine_score                      marijuana_score                       0.23
# agreeableness                       get_along_well_with_family_score      0.23
# income_bucket                       alcohol_score                         0.23
# nicotine_score                      has_used_psychedelics                 0.23
# extraversion                        get_along_well_with_family_score      0.23
# neuroticism                         politics_importance_score             0.23
# conscientiousness                   extraversion                          0.23
# agreeableness                       openness                              0.22
# income_bucket                       behavioral_health_score               0.22
# height_inches                       behavioral_health_score               0.22
# alcohol_score                       sex_partners_score                    0.21
# conscientiousness                   hard_work_and_success_belief_score    0.20
# neuroticism                         openness                             -0.24
#                                     behavioral_health_score              -0.24
# extraversion                        neuroticism                          -0.28
# religion_importance_score           casual_sex_score                     -0.40
# political_tolerance_score           politics_importance_score            -0.45
# dtype: float64

# %% [markdown]
# ### Surprising Correlations:
# 1. **Height vs. Casual Sex (0.24):** Surprising correlation, as one might not immediately associate a person's height with their engagement in casual sexual activities.
#
# 2. **IQ Share vs. Politics Importance (0.24):** Intriguing correlation between intelligence quotient and the importance given to politics, suggesting a potential link between cognitive abilities and political interest.
#
# 3. **Income vs. Alcohol Score (0.23):** Notable correlation, indicating a relationship between income levels and alcohol consumption, which might present insights into spending habits or lifestyle choices associated with income.
#
# The rest of strong correlations are obvious ones.

# %% [markdown]
# ## Personality correlations
#
# ### Positive Correlations:
# 1. **Extraversion vs. Openness (0.40):** Indicates a substantial positive correlation between extraversion and openness. People who exhibit extraversion traits tend to be more open to new experiences.
#
# 2. **Agreeableness vs. Get Along Well with Family Score (0.23):** Suggests a moderate positive correlation. Individuals who score higher on agreeableness might have better family relationships.
#
# ### Negative Correlations:
# 1. **Extraversion vs. Neuroticism (-0.28):** Shows a moderate negative correlation. Individuals exhibiting higher levels of extraversion might have lower levels of neuroticism, indicating emotional stability.
#
# 2. **Neuroticism vs. Behavioral Health Score (-0.24):** Highlights a moderate negative correlation. Higher neuroticism might correlate with lower scores in behavioral health.

# %% [markdown]
# It would be interesting to separate the correlations for males/females

# %% [markdown]
# ### Correlations for males

# %%
#f, ax = plt.subplots(figsize=(20, 15))
#sns.heatmap(user_features[user_features['gender']=='male'].corr(numeric_only=True), annot=True, fmt=".2f", linewidths=.5, ax=ax)

# %%
male_big_corr = user_features[user_features['gender'] == 'male'].corr(numeric_only=True)[(user_features[user_features['gender'] == 'male'].corr(numeric_only=True) > 0.2) | (user_features[user_features['gender'] == 'male'].corr(numeric_only=True) < -0.2)]

# %%
f, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(male_big_corr, annot=True, fmt=".2f", linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %%
male_big_corr = male_big_corr[male_big_corr !=1]
round(male_big_corr.stack().drop_duplicates().sort_values(ascending=False),2)
# Out:
# marijuana_score                     has_used_psychedelics                 0.46
# religion_importance_score           politics_importance_score             0.44
# extraversion                        openness                              0.42
#                                     get_along_well_with_family_score      0.33
# conscientiousness                   extraversion                          0.32
# avg_physical_attractiveness_rating  behavioral_health_score               0.29
# iq_share_correct                    openness                              0.29
#                                     income_bucket                         0.28
# nicotine_score                      has_used_psychedelics                 0.28
# sex_partners_score                  casual_sex_score                      0.28
# avg_physical_attractiveness_rating  sex_partners_score                    0.27
# income_bucket                       casual_sex_score                      0.27
# nicotine_score                      marijuana_score                       0.26
# income_bucket                       behavioral_health_score               0.26
# agreeableness                       openness                              0.26
# iq_share_correct                    agreeableness                         0.25
# avg_physical_attractiveness_rating  income_bucket                         0.25
# age                                 already_has_kids                      0.25
# openness                            get_along_well_with_family_score      0.25
# agreeableness                       get_along_well_with_family_score      0.24
# sex_partners_score                  already_has_kids                      0.24
# income_bucket                       get_along_well_with_family_score      0.24
# conscientiousness                   hard_work_and_success_belief_score    0.24
# openness                            income_bucket                         0.24
# income_bucket                       sex_partners_score                    0.23
# avg_physical_attractiveness_rating  casual_sex_score                      0.22
# age                                 income_bucket                         0.22
# income_bucket                       alcohol_score                         0.21
# alcohol_score                       casual_sex_score                      0.21
# has_used_psychedelics               political_tolerance_score             0.20
# conscientiousness                   openness                              0.20
# neuroticism                         politics_importance_score             0.20
# iq_share_correct                    ethnicity_importance_score           -0.23
# neuroticism                         get_along_well_with_family_score     -0.25
#                                     behavioral_health_score              -0.26
#                                     openness                             -0.26
# religion_importance_score           casual_sex_score                     -0.30
# political_tolerance_score           politics_importance_score            -0.32
# extraversion                        neuroticism                          -0.34
# dtype: float64

# %% [markdown]
# ### Correlations for females

# %%
female_big_corr = user_features[user_features['gender'] == 'female'].corr(numeric_only=True)[(user_features[user_features['gender'] == 'female'].corr(numeric_only=True) > 0.2) | (user_features[user_features['gender'] == 'female'].corr(numeric_only=True) < -0.2)]

# %%
f, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(female_big_corr, annot=True, fmt=".2f", linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %%
female_big_corr = female_big_corr[female_big_corr !=1]
round(female_big_corr.stack().drop_duplicates().sort_values(ascending=False),2)
# Out:
# marijuana_score                     has_used_psychedelics                 0.44
# age                                 already_has_kids                      0.41
# sex_partners_score                  casual_sex_score                      0.39
# extraversion                        openness                              0.37
# avg_physical_attractiveness_rating  behavioral_health_score               0.36
# age                                 income_bucket                         0.31
# has_used_psychedelics               sex_partners_score                    0.28
#                                     casual_sex_score                      0.28
# iq_share_correct                    politics_importance_score             0.27
# income_bucket                       alcohol_score                         0.27
# conscientiousness                   behavioral_health_score               0.24
# agreeableness                       get_along_well_with_family_score      0.24
# alcohol_score                       sex_partners_score                    0.24
# extraversion                        alcohol_score                         0.23
# iq_share_correct                    income_bucket                         0.22
# religion_importance_score           num_children_wanted_score             0.22
#                                     politics_importance_score             0.22
# iq_share_correct                    agreeableness                         0.22
# political_tolerance_score           already_has_kids                      0.21
# iq_share_correct                    openness                              0.20
# nicotine_score                      marijuana_score                       0.20
# political_tolerance_score           hard_work_and_success_belief_score    0.20
# iq_share_correct                    political_tolerance_score            -0.21
# num_children_wanted_score           casual_sex_score                     -0.23
# has_used_psychedelics               ethnicity_importance_score           -0.23
# agreeableness                       neuroticism                          -0.24
# politics_importance_score           already_has_kids                     -0.25
# age                                 num_children_wanted_score            -0.25
# extraversion                        neuroticism                          -0.25
# neuroticism                         openness                             -0.25
# religion_importance_score           casual_sex_score                     -0.38
# political_tolerance_score           politics_importance_score            -0.50
# dtype: float64

# %%
# Calculate correlations for male and female separately
corr_male = user_features[user_features['gender'] == 'male'].corr(numeric_only=True)
corr_female = user_features[user_features['gender'] == 'female'].corr(numeric_only=True)
corr_diff = corr_male - corr_female

f, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(corr_diff, annot=True, fmt=".2f", linewidths=.5, cmap='coolwarm', ax=ax)
# Out:
# <Axes: >

# %%
# Filter so we only see the differences in correlations > 0.2
filtered_values = corr_diff[(corr_diff < -0.2) | (corr_diff >0.2)]

# %%
# Visualize the differences
plt.figure(figsize=(20, 14))
sns.heatmap(filtered_values, annot=True, fmt=".2f", linewidths=.5, cmap='coolwarm')
plt.title('Biggest differences between genders', fontsize=18)
plt.show()

# %%
round(filtered_values.stack().drop_duplicates().sort_values(ascending=False),2)
# Out:
# iq_share_correct                  political_tolerance_score           0.32
# get_along_well_with_family_score  already_has_kids                    0.25
# religion_importance_score         politics_importance_score           0.22
# income_bucket                     casual_sex_score                    0.22
# ethnicity_importance_score        politics_importance_score           0.21
# behavioral_health_score           casual_sex_score                    0.21
# extraversion                      get_along_well_with_family_score    0.21
# income_bucket                     sex_partners_score                  0.21
# nicotine_score                    already_has_kids                   -0.22
# has_used_psychedelics             casual_sex_score                   -0.26
# dtype: float64

# %% [markdown]
# ### Conclusions from Correlation Differences (Males vs. Females)
#
# 1. **IQ Share Correct vs. Political Tolerance Score (0.32):** Indicates a notably stronger relationship in males regarding how IQ share correlates with political tolerance compared to females.
#
# 2. **Already Has Kids vs. Get Along Well with Family Score (0.25):** Suggests that the association between having kids and family relations is more pronounced in males.
#
# 3. **Politics Importance Score vs. Religion Importance Score (0.22):** Higher correlation difference highlights a potentially stronger link in males between politics and religion importance.
#
# 4. **Income Bucket vs. Casual Sex Score (0.22):** Implies a potentially more marked relationship between income and casual sex in males.
#
# 5. **Ethnicity Importance Score vs. Politics Importance Score (0.21):** Indicates a stronger relationship between ethnicity and politics importance among males.
#
# 6. **Casual Sex Score vs. Behavioral Health Score (0.21):** Highlights a potentially stronger connection between casual sex and behavioral health in males.
#
# 7. **Extraversion vs. Get Along Well with Family Score (0.21):** Points to a potentially stronger link between extraversion and familial relations in males.
#
# 8. **Sex Partners Score vs. Income Bucket (0.21):** Suggests a potentially more pronounced relationship between the number of sex partners and income among males.

# %% [markdown]
# ### Unique to women:
#
# 1. **Has Used Psychedelics vs. Casual Sex Score (-0.26):** The stronger negative correlation in females implies that among females, the relationship between using psychedelics and engaging in casual sex is more prominent compared to males.
#
# 2. **Already Has Kids vs. Nicotine Score (-0.22):** The negative correlation is stronger in females compared to males. This suggests that among females, there's a more pronounced relationship between having kids and lower nicotine scores than observed in males.

# %% [markdown]
# #### 2. Outcomes Distribution:
# Visualize the distribution of outcomes (e.g., mutual interest) to understand how frequently mutual interest occurs in these speed dates. It might reveal patterns or trends.

# %% [markdown]
# #### 3. Physical Attractiveness vs. Likability:
# Plotting physical attractiveness against likability or success rate in dates can show if there's any visible correlation between physical appearance and the outcomes.

# %% [markdown]
# #### 4. IQ vs. Likability:
# Analyze whether higher IQs correlate with increased likability or success in these speed dates.

# %% [markdown]
# #### 5. Personality Traits vs. Likability:
# Explore if certain personality traits (like extraversion, agreeableness, etc.) correlate with a higher likelihood of mutual interest.

# %% [markdown]
# #### 6. Income vs. Likability:
# Check if there's any correlation between income levels and likability or mutual interest during these speed dates.

# %% [markdown]
# #### 7. Drug Use vs. Likability:
# Investigate if drug use (nicotine, alcohol, marijuana, psychedelics) has any correlation with the success of these dates.

# %% [markdown]
# #### 8. Height vs. Likability:
# Explore if there's any relationship between height and the outcomes of these dates.

# %% [markdown]
# #### 9. Values/Importance Scores vs. Likability:
# Analyze if factors like religion, ethnicity, politics, or family values/importance have any correlation with the outcomes.

# %% [markdown]
# #### 10. Number of Children Wanted vs. Likability:
# Check if preferences regarding the number of children correlate with the success of dates.
